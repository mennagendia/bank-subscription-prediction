# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/custom-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting category_encoders (from -r ./requirements.txt (line 2))
#   Downloading category_encoders-2.8.1-py3-none-any.whl.metadata (7.9 kB)
#   Downloading category_encoders-2.8.0-py3-none-any.whl.metadata (7.9 kB)
# Requirement already satisfied: pip in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 4)) (24.0)
# Requirement already satisfied: seaborn==0.13.2 in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 5)) (0.13.2)
# Requirement already satisfied: plotly==6.0.0 in /root/venv/lib/python3.11/site-packages (from -r ./requirements.txt (line 6)) (6.0.0)
# Collecting imblearn==0.0 (from -r ./requirements.txt (line 7))
#   Downloading imblearn-0.0-py2.py3-none-any.whl.metadata (355 bytes)
# Collecting xgboost==2.1.4 (from -r ./requirements.txt (line 9))
#   Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl.metadata (2.1 kB)
# Collecting cloudpickle==3.1.1 (from -r ./requirements.txt (line 10))
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting streamlit-lottie (from -r ./requirements.txt (line 13))
#   Downloading streamlit_lottie-0.0.5-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: numpy>=1.14.0 in /root/venv/lib/python3.11/site-packages (from category_encoders->-r ./requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: pandas>=1.0.5 in /root/venv/lib/python3.11/site-packages (from category_encoders->-r ./requirements.txt (line 2)) (2.1.4)
# Collecting patsy>=0.5.1 (from category_encoders->-r ./requirements.txt (line 2))
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting scikit-learn>=1.6.0 (from category_encoders->-r ./requirements.txt (line 2))
#   Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.0.0 in /root/venv/lib/python3.11/site-packages (from category_encoders->-r ./requirements.txt (line 2)) (1.11.4)
# Collecting statsmodels>=0.9.0 (from category_encoders->-r ./requirements.txt (line 2))
#   Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /root/venv/lib/python3.11/site-packages (from seaborn==0.13.2->-r ./requirements.txt (line 5)) (3.8.4)
# Requirement already satisfied: narwhals>=1.15.1 in /root/venv/lib/python3.11/site-packages (from plotly==6.0.0->-r ./requirements.txt (line 6)) (1.26.0)
# Requirement already satisfied: packaging in /root/venv/lib/python3.11/site-packages (from plotly==6.0.0->-r ./requirements.txt (line 6)) (24.2)
# Collecting imbalanced-learn (from imblearn==0.0->-r ./requirements.txt (line 7))
#   Downloading imbalanced_learn-0.13.0-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: nvidia-nccl-cu12 in /root/venv/lib/python3.11/site-packages (from xgboost==2.1.4->-r ./requirements.txt (line 9)) (2.18.1)
# Collecting streamlit>=0.63 (from streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading streamlit-1.43.2-py2.py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (1.4.8)
# Requirement already satisfied: pillow>=8 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /root/venv/lib/python3.11/site-packages (from matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders->-r ./requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas>=1.0.5->category_encoders->-r ./requirements.txt (line 2)) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /root/venv/lib/python3.11/site-packages (from scikit-learn>=1.6.0->category_encoders->-r ./requirements.txt (line 2)) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /root/venv/lib/python3.11/site-packages (from scikit-learn>=1.6.0->category_encoders->-r ./requirements.txt (line 2)) (3.5.0)
# Requirement already satisfied: altair<6,>=4.0 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (4.2.2)
# Collecting blinker<2,>=1.0.0 (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: cachetools<6,>=4.0 in /root/venv/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /root/venv/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (8.1.8)
# Requirement already satisfied: protobuf<6,>=3.20 in /root/venv/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (4.25.6)
# Requirement already satisfied: pyarrow>=7.0 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (17.0.0)
# Requirement already satisfied: requests<3,>=2.27 in /root/venv/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (9.0.0)
# Collecting toml<2,>=0.10.1 (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in /root/venv/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (4.12.2)
# Collecting watchdog<7,>=2.1.5 (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━���━━━━━━━━━━━ 44.3/44.3 kB 6.1 MB/s eta 0:00:00
# Collecting gitpython!=3.1.19,<4,>=3.0.7 (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading GitPython-3.1.44-py3-none-any.whl.metadata (13 kB)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: tornado<7,>=6.0.3 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (6.4.1)
# Collecting sklearn-compat<1,>=0.1 (from imbalanced-learn->imblearn==0.0->-r ./requirements.txt (line 7))
#   Downloading sklearn_compat-0.1.3-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: entrypoints in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (0.4)
# Requirement already satisfied: jinja2 in /root/venv/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (3.1.5)
# Requirement already satisfied: jsonschema>=3.0 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (4.23.0)
# Requirement already satisfied: toolz in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (0.12.1)
# Collecting gitdb<5,>=4.0.1 (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn==0.13.2->-r ./requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /root/venv/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.11/site-packages (from requests<3,>=2.27->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (2025.1.31)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /root/venv/lib/python3.11/site-packages (from jinja2->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /root/venv/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (25.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /toolkit-cache/0.2.11/python3.11/kernel-libs/lib/python3.11/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=0.63->streamlit-lottie->-r ./requirements.txt (line 13)) (0.20.0)
# Downloading category_encoders-2.8.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.7/85.7 kB 11.2 MB/s eta 0:00:00
# Downloading imblearn-0.0-py2.py3-none-any.whl (1.9 kB)
# Downloading xgboost-2.1.4-py3-none-manylinux_2_28_x86_64.whl (223.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 223.6/223.6 MB 11.4 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading streamlit_lottie-0.0.5-py3-none-any.whl (802 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 802.4/802.4 kB 87.7 MB/s eta 0:00:00
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 232.9/232.9 kB 44.8 MB/s eta 0:00:00
# Downloading scikit_learn-1.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.5/13.5 MB 126.3 MB/s eta 0:00:00
# Downloading statsmodels-0.14.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (10.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.8/10.8 MB 83.3 MB/s eta 0:00:00
# Downloading streamlit-1.43.2-py2.py3-none-any.whl (9.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.7/9.7 MB 108.7 MB/s eta 0:00:00
# Downloading imbalanced_learn-0.13.0-py3-none-any.whl (238 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 238.4/238.4 kB 49.0 MB/s eta 0:00:00
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading GitPython-3.1.44-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.6/207.6 kB 47.6 MB/s eta 0:00:00
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 133.4 MB/s eta 0:00:00
# Downloading sklearn_compat-0.1.3-py3-none-any.whl (18 kB)
# Downloading toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Downloading watchdog-6.0.0-py3-none-manylinux2014_x86_64.whl (79 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.1/79.1 kB 20.0 MB/s eta 0:00:00
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 16.1 MB/s eta 0:00:00
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Installing collected packages: watchdog, toml, smmap, patsy, cloudpickle, blinker, xgboost, scikit-learn, pydeck, gitdb, statsmodels, sklearn-compat, gitpython, imbalanced-learn, category_encoders, streamlit, imblearn, streamlit-lottie
#   Attempting uninstall: cloudpickle
#     Found existing installation: cloudpickle 2.2.1
#     Uninstalling cloudpickle-2.2.1:
#       Successfully uninstalled cloudpickle-2.2.1
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.3.2
#     Uninstalling scikit-learn-1.3.2:
#       Successfully uninstalled scikit-learn-1.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# snowflake-snowpark-python 1.26.0 requires cloudpickle!=2.1.0,!=2.2.0,<=2.2.1,>=1.6.0, but you have cloudpickle 3.1.1 which is incompatible.
# Successfully installed blinker-1.9.0 category_encoders-2.8.0 cloudpickle-3.1.1 gitdb-4.0.12 gitpython-3.1.44 imbalanced-learn-0.13.0 imblearn-0.0 patsy-1.0.1 pydeck-0.9.1 scikit-learn-1.6.1 sklearn-compat-0.1.3 smmap-5.0.2 statsmodels-0.14.4 streamlit-1.43.2 streamlit-lottie-0.0.5 toml-0.10.2 watchdog-6.0.0 xgboost-2.1.4
#
# [notice] A new release of pip is available: 24.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
